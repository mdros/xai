# %%
results = {
    "Law": {
        'coverage': 1.0,
        'validity': 0.6216216216216216,
        'actionability': 0.20045045045045046,
        'sparsity': 0.7995495495495496,
        'proximity_categorical_hamming': np.nan,
        'proximity_categorical_jaccard': 0.1747434908992034,
        'proximity_continuous_manhattan': 0.2953791396179493,
        'proximity_continuous_euclidean': 0.1747434908992034,
        'proximity_continuous_mad': 2.469260804409134,
        'proximity_l2_jaccard': 0.1747434908992034,
        'proximity_mad_hamming': np.nan,
        'prob_plausibility': 1.0,
        'log_density_cf': 1.6123302,
        'log_density_test': 0.0727248,
        'lof_scores_cf': 1.0429159,
        'lof_scores_test': 1.0629689,
        'isolation_forest_scores_cf': 0.0517592142653124,
        'isolation_forest_scores_test': 0.029737427250345106
    },
    "Wine": {
        'coverage': 1.0,
            'validity': 1.0,
            'actionability': 0.0,
            'sparsity': 0.9978632478632479,
            'proximity_categorical_hamming': nan,
            'proximity_categorical_jaccard': 0.3567284325657089,
            'proximity_continuous_manhattan': 1.115057898982842,
            'proximity_continuous_euclidean': 0.3567284325657089,
            'proximity_continuous_mad': 8.275870707299974,
            'proximity_l2_jaccard': 0.3567284325657089,
            'proximity_mad_hamming': nan,
            'prob_plausibility': 0.9444444444444444,
            'log_density_cf': 4.728581,
            'log_density_test': -4.348091,
            'lof_scores_cf': 1.0247798,
            'lof_scores_test': 1.083412,
            'isolation_forest_scores_cf': 0.06842495049559408,
            'isolation_forest_scores_test': 0.03483643362366132
    },
    "Moons": {
        'coverage': 1.0,
            'validity': 1.0,
            'actionability': 0.0,
            'sparsity': 1.0,
            'proximity_categorical_hamming': nan,
            'proximity_categorical_jaccard': 0.27648498851905734,
            'proximity_continuous_manhattan': 0.3554813292331812,
            'proximity_continuous_euclidean': 0.27648498851905734,
            'proximity_continuous_mad': 1.8272110244122948,
            'proximity_l2_jaccard': 0.27648498851905734,
            'proximity_mad_hamming': nan,
            'prob_plausibility': 0.9951219512195122,
            'log_density_cf': 1.367367,
            'log_density_test': -36.42818,
            'lof_scores_cf': 1.04192,
            'lof_scores_test': 1.0409402,
            'isolation_forest_scores_cf': 0.027092389010673755,
            'isolation_forest_scores_test': 0.0041604418163049064
    },
    "Netflix Titles": {'coverage': 1.0,
        'validity': 0.9693181818181819,
        'actionability': 0.09488636363636363,
        'sparsity': 0.9051136363636364,
        'proximity_categorical_hamming': 0.8142011977508523,
        'proximity_categorical_jaccard': 0.8142011977508523,
        'proximity_continuous_manhattan': 0.8187039034653473,
        'proximity_continuous_euclidean': 0.8142011977508523,
        'proximity_continuous_mad': 1.9302398575096449,
        'proximity_l2_jaccard': 0.8142011977508523,
        'proximity_mad_hamming': 1.9302398575096449,
        'prob_plausibility': 0.7471590909090909,
        'log_density_cf': 69.9904,
        'log_density_test': 37.34087,
        'lof_scores_cf': 46647844.0,
        'lof_scores_test': 1089414.9,
        'isolation_forest_scores_cf': 0.0767617504134978,
        'isolation_forest_scores_test': 0.09178902924334606
    },
    // others
    "German Credit": {'coverage': 1.0,
        'validity': 0.65,
        'actionability': 0.14166666666666666,
        'sparsity': 0.8580409356725146,
        'proximity_categorical_hamming': 0.7799560093909939,
        'proximity_categorical_jaccard': 0.6141890278345388,
        'proximity_continuous_manhattan': 0.6556664725228718,
        'proximity_continuous_euclidean': 0.6141890278345388,
        'proximity_continuous_mad': 1.0053072366993714,
        'proximity_l2_jaccard': 0.6141890278345388,
        'proximity_mad_hamming': 1.1710742182558267,
        'prob_plausibility': 1.0,
        'log_density_cf': -10.40897,
        'log_density_test': -14.123992,
        'lof_scores_cf': 1.0274575,
        'lof_scores_test': 1.0363257,
        'isolation_forest_scores_cf': 0.013081027773655189,
        'isolation_forest_scores_test': 0.03140577863894244},
    "Digits": {'coverage': 1.0,
        'validity': 0.8972222222222223,
        'actionability': 0.5555555555555556,
        'sparsity': 0.44114583333333335,
        'proximity_categorical_hamming': nan,
        'proximity_categorical_jaccard': 0.17294361829826818,
        'proximity_continuous_manhattan': 1.2148535747310887,
        'proximity_continuous_euclidean': 0.17294361829826818,
        'proximity_continuous_mad': 4.719014181145086,
        'proximity_l2_jaccard': 0.17294361829826818,
        'proximity_mad_hamming': nan,
        'prob_plausibility': 0.8944444444444445,
        'log_density_cf': -53.09069,
        'log_density_test': 16.866123,
        'lof_scores_cf': 1.139849,
        'lof_scores_test': 1.0452181,
        'isolation_forest_scores_cf': 0.019408738300851748,
        'isolation_forest_scores_test': 0.018654854560416018
    }
}

# %% [markdown]
# **Law**
# Coverage: 1.0 - All instances have counterfactuals.
# Validity: 0.62 - 62% achieve the desired outcome.
# Actionability: 0.20 - 20% suggest actionable changes.
# Sparsity: 0.80 - Few changes needed.
# Proximity: Mixed, some NaN - Closeness to original instances.
# Plausibility: 1.0 - All plausible.
# Density Scores: High for counterfactuals (1.61), low for test data (0.07).
# Anomaly Scores: Similar for both counterfactuals and test data.
#
# **Wine**
# Coverage: 1.0 - All instances have counterfactuals.
# Validity: 1.0 - All achieve the desired outcome.
# Actionability: 0.0 - None suggest actionable changes.
# Sparsity: 0.998 - Very few changes needed.
# Proximity: Mixed, some NaN - Closeness to original instances.
# Plausibility: 0.94 - Most plausible.
# Density Scores: High for counterfactuals (4.73), negative for test data (-4.35).
# Anomaly Scores: Similar for both counterfactuals and test data.
#
# **Moons**
# Coverage: 1.0 - All instances have counterfactuals.
# Validity: 1.0 - All achieve the desired outcome.
# Actionability: 0.0 - None suggest actionable changes.
# Sparsity: 1.0 - Very few changes needed.
# Proximity: Mixed, some NaN - Closeness to original instances.
# Plausibility: 0.99 - Most plausible.
# Density Scores: Moderate for counterfactuals (1.37), very low for test data (-36.43).
# Anomaly Scores: Similar for both counterfactuals and test data.
#
# **Netflix Titles**
# Coverage: 1.0 - All instances have counterfactuals.
# Validity: 0.97 - Most achieve the desired outcome.
# Actionability: 0.09 - Few suggest actionable changes.
# Sparsity: 0.91 - Few changes needed.
# Proximity: High - Closeness to original instances.
# Plausibility: 0.75 - Many plausible.
# Density Scores: Very high for counterfactuals (69.99), high for test data (37.34).
# Anomaly Scores: Extremely high for counterfactuals (46647844.0) compared to test data (1089414.9).
#
# **German Credit**
# Coverage: 1.0 - All instances have counterfactuals.
# Validity: 0.65 - 65% achieve the desired outcome.
# Actionability: 0.14 - Few suggest actionable changes.
# Sparsity: 0.86 - Few changes needed.
# Proximity: Mixed - Closeness to original instances.
# Plausibility: 1.0 - All plausible.
# Density Scores: Negative for counterfactuals (-10.41), lower for test data (-14.12).
# Anomaly Scores: Similar for both counterfactuals and test data.
#
# **Digits**
# Coverage: 1.0 - All instances have counterfactuals.
# Validity: 0.90 - Most achieve the desired outcome.
# Actionability: 0.56 - Some suggest actionable changes.
# Sparsity: 0.44 - Moderate changes needed.
# Proximity: Mixed, some NaN - Closeness to original instances.
# Plausibility: 0.89 - Most plausible.
# Density Scores: Very negative for counterfactuals (-53.09), positive for test data (16.87).
# Anomaly Scores: Similar for both counterfactuals and test data.
#
# Overall, the results show varying degrees of scores across datasets. Proximity metrics are mixed, and plausibility is usually high. Density and anomaly scores vary significantly between counterfactuals and test data.
#
# Coverage tells us how much data is covered by counterfactuals
# Validity tells us the amount of counterfactuals achieve the desired outcome
# Actionability tells us how many counterfactuals suggest actionable changes
# Sparsity tells us how many features on average we need to change to achieve the counterfactual
# Proximity tells us how close are the counterfactuals to the original data
# Plausability tells us how much are the counterfactuals plausible withing the data distribution
# Density tells us about density of counterfactuals in the feature space
